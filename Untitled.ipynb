# %%
from pycspade.helpers import spade, print_result

# %%
result = spade(filename='data1.txt', support=0.8, parse=True)

# %%
print_result(result)
# Out:
#    Occurs     Accum   Support    Confid      Lift                                                                         Sequence
#       179       179 0.8287037       N/A       N/A                                                                             (10)
#       199       199 0.9212963       N/A       N/A                                                                              (4)
#       205       205 0.9490741       N/A       N/A                                                                              (5)
#       205       205 0.9490741       N/A       N/A                                                                              (6)
#       204       204 0.9444444       N/A       N/A                                                                              (7)
#       207       207 0.9583333       N/A       N/A                                                                              (8)
# ...

# %%
result
# Out:
# {'nsequences': 216,
# ...
